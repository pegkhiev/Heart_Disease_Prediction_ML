# %%
import pandas as pd
import numpy as np
from path import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import sqlite3

# %%
#connect to database
path = "model/db/HeartDiseaseByCounty.db"
cnx = sqlite3.connect(path)

# %%
#Display tables from provisional database
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", cnx)
# Out:
#                                      name
# 0                                   State
# 1  Heart_Disease_Mortality_State_Counties
# 2               Population_State_Counties
# 3                 Features_State_Counties

# %%
#Read all tables from provisional database into DataFrames
df_features = pd.read_sql_query("SELECT * FROM Features_State_Counties", cnx)
df_features.head()
# Out:
#   State_Name   County  Percent_Fair_or_Poor_Health  \
# 0    Alabama  Autauga                           21
# 1    Alabama  Baldwin                           18
# 2    Alabama  Barbour                           30
# 3    Alabama     Bibb                           19
# 4    Alabama   Blount                           22
#
#    Average_Number_of_Physically_Unhealthy_Days  \
# 0                                          4.7
# 1                                          4.2
# 2                                          5.4
# 3                                          4.6
# 4                                          4.9
#
#    Average_Number_of_Mentally_Unhealthy_Days  Percent_Smokers  \
# 0                                        4.7               18
# 1                                        4.3               17
# 2                                        5.2               22
# 3                                        4.6               19
# 4                                        4.9               19
#
#    Percent_Adults_with_Obesity  Food_Environment_Index  \
# 0                           33                     7.2
# 1                           31                     8.0
# 2                           42                     5.6
# 3                           38                     7.8
# 4                           34                     8.4
#
#    Percent_Physically_Inactive  Percent_With_Access_to_Exercise_Opportunities  \
# 0                           35                                             69
# 1                           27                                             74
# 2                           24                                             53
# 3                           34                                             16
# 4                           30                                             16
#
#    ...  Population_Asian  Population_NHPI  Population_Hispanic  \
# 0  ...               681               62                 1649
# 1  ...              2508              146                10131
# 2  ...               113               46                 1064
# 3  ...                53               26                  588
# 4  ...               185               70                 5536
#
#    Population_NHW  Percent_Insufficient_Sleep  \
# 0           41316                          36
# 1          181201                          33
# 2           11356                          39
# 3           16708                          38
# 4           50255                          36
#
#    Average_Traffic_Volume_per_Meter_of_Major_Roadways  Percent_Homeowners  \
# 0                                                 88                   75
# 1                                                 87                   74
# 2                                                102                   61
# 3                                                 29                   75
# 4                                                 33                   79
#
#    Percent_Severe_Housing_Cost_Burden  Percent_Children_in_Poverty  \
# 0                                13.0                         19.0
# 1                                12.0                         14.0
# 2                                14.0                         44.0
# 3                                10.0                         28.0
# 4                                 8.0                         18.0
#
#    Teen_Birth_Rate
# 0             25.0
# 1             28.0
# 2             41.0
# 3             42.0
# 4             34.0
#
# [5 rows x 49 columns]

# %%
df_state = pd.read_sql_query("SELECT * FROM State", cnx)
df_state.head()
# Out:
#          Name Code
# 0      Alaska   AK
# 1     Alabama   AL
# 2    Arkansas   AR
# 3     Arizona   AZ
# 4  California   CA

# %%
df_pop = pd.read_sql_query("SELECT * FROM Population_state_counties", cnx)
df_pop.head()
# Out:
#   State_Code          County   PopEst
# 0         AK  Aleutians East    3,337
# 1         AK  Aleutians West    5,634
# 2         AK       Anchorage  288,000
# 3         AK          Bethel   18,386
# 4         AK     Bristol Bay      836

# %%
df_mortality = pd.read_sql_query("SELECT * FROM Heart_disease_mortality_state_counties", cnx)
df_mortality.head()
# Out:
#   State_Code          County        Rate  Level
# 0         AK  Aleutians East  165.000000      1
# 1         AK  Aleutians West  261.800000      1
# 2         AK       Anchorage  261.733333      1
# 3         AK          Bethel  321.322222      2
# 4         AK     Bristol Bay    0.000000      1

# %%
#Pre-process data - standardize and convert all State names into State codes
statename = df_state["Name"].values.tolist()

# %%
symbol = df_state["Code"].values.tolist()

# %%
#Pre-process data - transform State_Name into codes for later merging 
df_features.replace(to_replace = statename, value = symbol, inplace = True)
df_features.tail()
# Out:
#      State_Name      County  Percent_Fair_or_Poor_Health  \
# 3137         WY  Sweetwater                           15
# 3138         WY       Teton                           12
# 3139         WY       Uinta                           16
# 3140         WY    Washakie                           16
# 3141         WY      Weston                           14
#
#       Average_Number_of_Physically_Unhealthy_Days  \
# 3137                                          3.4
# 3138                                          3.0
# 3139                                          3.6
# 3140                                          3.6
# 3141                                          3.5
#
#       Average_Number_of_Mentally_Unhealthy_Days  Percent_Smokers  \
# 3137                                        3.6               18
# 3138                                        3.2               15
# 3139                                        3.7               17
# 3140                                        3.7               17
# 3141                                        3.7               17
#
#       Percent_Adults_with_Obesity  Food_Environment_Index  \
# 3137                           30                     7.7
# 3138                           12                     8.2
# 3139                           36                     7.4
# 3140                           29                     8.3
# 3141                           33                     7.9
#
#       Percent_Physically_Inactive  \
# 3137                           25
# 3138                           12
# 3139                           27
# 3140                           28
# 3141                           27
#
#       Percent_With_Access_to_Exercise_Opportunities  ...  Population_Asian  \
# 3137                                             90  ...               435
# 3138                                            100  ...               326
# 3139                                             84  ...                96
# 3140                                             83  ...                65
# 3141                                             63  ...               135
#
#       Population_NHPI  Population_Hispanic  Population_NHW  \
# 3137               68                 6924           34145
# 3138               35                 3434           18812
# 3139               30                 1875           17741
# 3140                8                 1108            6498
# 3141                2                  284            6267
#
#       Percent_Insufficient_Sleep  \
# 3137                          31
# 3138                          27
# 3139                          31
# 3140                          28
# 3141                          30
#
#       Average_Traffic_Volume_per_Meter_of_Major_Roadways  Percent_Homeowners  \
# 3137                                                155                   75
# 3138                                                135                   58
# 3139                                                 96                   75
# 3140                                                 83                   77
# 3141                                                 64                   78
#
#       Percent_Severe_Housing_Cost_Burden  Percent_Children_in_Poverty  \
# 3137                                 NaN                          NaN
# 3138                                 NaN                          NaN
# 3139                                 NaN                          NaN
# 3140                                 NaN                          NaN
# 3141                                 NaN                          NaN
#
#       Teen_Birth_Rate
# 3137              NaN
# 3138              NaN
# 3139              NaN
# 3140              NaN
# 3141              NaN
#
# [5 rows x 49 columns]

# %%
#Merge first two DataFrames together
df_combined1 = df_features.merge(df_mortality, left_on = ["State_Name","County"], right_on = ["State_Code","County"])
df_combined1.head()
# Out:
#   State_Name   County  Percent_Fair_or_Poor_Health  \
# 0         AL  Autauga                           21
# 1         AL  Baldwin                           18
# 2         AL  Barbour                           30
# 3         AL     Bibb                           19
# 4         AL   Blount                           22
#
#    Average_Number_of_Physically_Unhealthy_Days  \
# 0                                          4.7
# 1                                          4.2
# 2                                          5.4
# 3                                          4.6
# 4                                          4.9
#
#    Average_Number_of_Mentally_Unhealthy_Days  Percent_Smokers  \
# 0                                        4.7               18
# 1                                        4.3               17
# 2                                        5.2               22
# 3                                        4.6               19
# 4                                        4.9               19
#
#    Percent_Adults_with_Obesity  Food_Environment_Index  \
# 0                           33                     7.2
# 1                           31                     8.0
# 2                           42                     5.6
# 3                           38                     7.8
# 4                           34                     8.4
#
#    Percent_Physically_Inactive  Percent_With_Access_to_Exercise_Opportunities  \
# 0                           35                                             69
# 1                           27                                             74
# 2                           24                                             53
# 3                           34                                             16
# 4                           30                                             16
#
#    ...  Population_NHW  Percent_Insufficient_Sleep  \
# 0  ...           41316                          36
# 1  ...          181201                          33
# 2  ...           11356                          39
# 3  ...           16708                          38
# 4  ...           50255                          36
#
#    Average_Traffic_Volume_per_Meter_of_Major_Roadways  Percent_Homeowners  \
# 0                                                 88                   75
# 1                                                 87                   74
# 2                                                102                   61
# 3                                                 29                   75
# 4                                                 33                   79
#
#    Percent_Severe_Housing_Cost_Burden  Percent_Children_in_Poverty  \
# 0                                13.0                         19.0
# 1                                12.0                         14.0
# 2                                14.0                         44.0
# 3                                10.0                         28.0
# 4                                 8.0                         18.0
#
#    Teen_Birth_Rate  State_Code        Rate  Level
# 0             25.0          AL  422.022222      4
# 1             28.0          AL  321.570588      2
# 2             41.0          AL  461.144444      4
# 3             42.0          AL  393.036364      3
# 4             34.0          AL  387.481818      3
#
# [5 rows x 52 columns]

# %%
df_combined1.shape
# Out:
# (3013, 52)

# %%
#Pre-process data - standardize County name and convert PopEst into integers
df_pop['County'] = df_pop["County"].str.replace(' County', "")
df_pop["PopEst"] = pd.to_numeric(df_pop["PopEst"].str.replace(',',''))
df_pop.head()
# Out:
#   State_Code          County    PopEst
# 0         AK  Aleutians East    3337.0
# 1         AK  Aleutians West    5634.0
# 2         AK       Anchorage  288000.0
# 3         AK          Bethel   18386.0
# 4         AK     Bristol Bay       NaN

# %%
df_pop.dropna(inplace = True)
df_pop.isnull().sum
# Out:
# <bound method DataFrame.sum of       State_Code  County  PopEst
# 0          False   False   False
# 1          False   False   False
# 2          False   False   False
# 3          False   False   False
# 5          False   False   False
# ...          ...     ...     ...
# 3137       False   False   False
# 3138       False   False   False
# 3139       False   False   False
# 3140       False   False   False
# 3141       False   False   False
#
# [3105 rows x 3 columns]>

# %%
#Merge all DataFrames together 

df_combined = df_combined1.merge(df_pop, how = "inner", left_on = ["State_Name","County"], right_on = ["State_Code","County"])
df_combined.head()
# Out:
#   State_Name   County  Percent_Fair_or_Poor_Health  \
# 0         AL  Autauga                           21
# 1         AL  Baldwin                           18
# 2         AL  Barbour                           30
# 3         AL     Bibb                           19
# 4         AL   Blount                           22
#
#    Average_Number_of_Physically_Unhealthy_Days  \
# 0                                          4.7
# 1                                          4.2
# 2                                          5.4
# 3                                          4.6
# 4                                          4.9
#
#    Average_Number_of_Mentally_Unhealthy_Days  Percent_Smokers  \
# 0                                        4.7               18
# 1                                        4.3               17
# 2                                        5.2               22
# 3                                        4.6               19
# 4                                        4.9               19
#
#    Percent_Adults_with_Obesity  Food_Environment_Index  \
# 0                           33                     7.2
# 1                           31                     8.0
# 2                           42                     5.6
# 3                           38                     7.8
# 4                           34                     8.4
#
#    Percent_Physically_Inactive  Percent_With_Access_to_Exercise_Opportunities  \
# 0                           35                                             69
# 1                           27                                             74
# 2                           24                                             53
# 3                           34                                             16
# 4                           30                                             16
#
#    ...  Average_Traffic_Volume_per_Meter_of_Major_Roadways  \
# 0  ...                                                 88
# 1  ...                                                 87
# 2  ...                                                102
# 3  ...                                                 29
# 4  ...                                                 33
#
#    Percent_Homeowners  Percent_Severe_Housing_Cost_Burden  \
# 0                  75                                13.0
# 1                  74                                12.0
# 2                  61                                14.0
# 3                  75                                10.0
# 4                  79                                 8.0
#
#    Percent_Children_in_Poverty  Teen_Birth_Rate  State_Code_x        Rate  \
# 0                         19.0             25.0            AL  422.022222
# 1                         14.0             28.0            AL  321.570588
# 2                         44.0             41.0            AL  461.144444
# 3                         28.0             42.0            AL  393.036364
# 4                         18.0             34.0            AL  387.481818
#
#    Level  State_Code_y    PopEst
# 0      4            AL   55869.0
# 1      2            AL  223234.0
# 2      4            AL   24686.0
# 3      3            AL   22394.0
# 4      3            AL   57826.0
#
# [5 rows x 54 columns]

# %%
# Drop State and county columns as they are identifier, and remove Level (classification target),
#Remove "Rate" (from which we derive mortality classes)

X = df_combined.copy()
X = X.drop([ "State_Name","County", "Rate","Level", "State_Code_x", "State_Code_y"], 1)
X = X.fillna(0)
X.head()
# Out:
#    Percent_Fair_or_Poor_Health  Average_Number_of_Physically_Unhealthy_Days  \
# 0                           21                                          4.7
# 1                           18                                          4.2
# 2                           30                                          5.4
# 3                           19                                          4.6
# 4                           22                                          4.9
#
#    Average_Number_of_Mentally_Unhealthy_Days  Percent_Smokers  \
# 0                                        4.7               18
# 1                                        4.3               17
# 2                                        5.2               22
# 3                                        4.6               19
# 4                                        4.9               19
#
#    Percent_Adults_with_Obesity  Food_Environment_Index  \
# 0                           33                     7.2
# 1                           31                     8.0
# 2                           42                     5.6
# 3                           38                     7.8
# 4                           34                     8.4
#
#    Percent_Physically_Inactive  Percent_With_Access_to_Exercise_Opportunities  \
# 0                           35                                             69
# 1                           27                                             74
# 2                           24                                             53
# 3                           34                                             16
# 4                           30                                             16
#
#    Percent_Excessive_Drinking  Percent_Uninsured  ...  Population_NHPI  \
# 0                          15                  9  ...               62
# 1                          18                 11  ...              146
# 2                          13                 12  ...               46
# 3                          16                 10  ...               26
# 4                          14                 13  ...               70
#
#    Population_Hispanic  Population_NHW  Percent_Insufficient_Sleep  \
# 0                 1649           41316                          36
# 1                10131          181201                          33
# 2                 1064           11356                          39
# 3                  588           16708                          38
# 4                 5536           50255                          36
#
#    Average_Traffic_Volume_per_Meter_of_Major_Roadways  Percent_Homeowners  \
# 0                                                 88                   75
# 1                                                 87                   74
# 2                                                102                   61
# 3                                                 29                   75
# 4                                                 33                   79
#
#    Percent_Severe_Housing_Cost_Burden  Percent_Children_in_Poverty  \
# 0                                13.0                         19.0
# 1                                12.0                         14.0
# 2                                14.0                         44.0
# 3                                10.0                         28.0
# 4                                 8.0                         18.0
#
#    Teen_Birth_Rate    PopEst
# 0             25.0   55869.0
# 1             28.0  223234.0
# 2             41.0   24686.0
# 3             42.0   22394.0
# 4             34.0   57826.0
#
# [5 rows x 48 columns]

# %%
#Target: Classification of mortality risks 
y = df_combined["Level"].ravel()
y[:5]
# Out:
# array([4, 2, 4, 3, 3], dtype=int64)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a random forest classifier.
rf_model = RandomForestClassifier(n_estimators=128, random_state=78)

# %%
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
predictions = rf_model.predict(X_test_scaled)

# %%
cm = confusion_matrix(y_test, predictions)

# Create a DataFrame from the confusion matrix.
cm_df = pd.DataFrame(
    cm, index=["Actual 1", "Actual 2", "Actual 3", "Actual 4"], columns=["Predicted 1", "Predicted 2", "Predicted 3", "Predicted 4"])

cm_df
# Out:
#           Predicted 1  Predicted 2  Predicted 3  Predicted 4
# Actual 1           99           72            1            2
# Actual 2           28          143           24           13
# Actual 3            5           50           45           58
# Actual 4            4           17           28          145

# %%
acc_score = accuracy_score(y_test, predictions)
display(cm_df)
print(f"Accuracy Score : {acc_score}")
print("Classification Report")
print(classification_report(y_test, predictions))
# Out:
#           Predicted 1  Predicted 2  Predicted 3  Predicted 4
# Actual 1           99           72            1            2
# Actual 2           28          143           24           13
# Actual 3            5           50           45           58
# Actual 4            4           17           28          145
# Accuracy Score : 0.5885558583106267
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.73      0.57      0.64       174
#            2       0.51      0.69      0.58       208
#            3       0.46      0.28      0.35       158
#            4       0.67      0.75      0.70       194
#
#     accuracy                           0.59       734
#    macro avg       0.59      0.57      0.57       734
# weighted avg       0.59      0.59      0.58       734

# %%
importances = rf_model.feature_importances_
sorted(zip(rf_model.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.04702523392253512, 'Median_Household_Income'),
#  (0.036660675306290906, 'Polution_Average_Daily_PM2.5'),
#  (0.03580422345554223, 'Average_Number_of_Mentally_Unhealthy_Days'),
#  (0.0356907743078979, 'Percent_Smokers'),
#  (0.03503685226070159, 'Household_Income_White'),
#  (0.03486490633113343, 'Percent_Fair_or_Poor_Health'),
#  (0.03377366387555132, 'Average_Number_of_Physically_Unhealthy_Days'),
#  (0.03146550473305125, 'Percent_Physically_Inactive'),
#  (0.030208971727716017, 'Population_Hispanic'),
#  (0.025977103417311652, 'Population_Asian'),
#  (0.025961096153320266, 'Preventable_Hospitalization_Rate'),
#  (0.022871837087735696, 'Population_NHPI'),
#  (0.022853371932235366, 'Percent_Some_College'),
#  (0.02212619291605177, 'Population_Black'),
#  (0.021982406528113188, 'Percent_Drive_Alone_to_Work'),
#  (0.02185229994412147, 'Population_AIAN'),
#  (0.02094378413977611, 'Social_Association_Rate'),
#  (0.020635889354100424, 'Average_Traffic_Volume_per_Meter_of_Major_Roadways'),
#  (0.020583987980151822, 'Population'),
#  (0.02053686088428959, 'PopEst'),
#  (0.020494043363630265, 'Violent_Crime_Rate'),
#  (0.020451791282781687, 'Percent_Excessive_Drinking'),
#  (0.019884267533266643, 'Percent_With_Access_to_Exercise_Opportunities'),
#  (0.019865505884742982, 'Percent_Adults_with_Obesity'),
#  (0.019775323273413706, 'Percent_Unemployed'),
#  (0.019521057313652595, 'Percent_Insufficient_Sleep'),
#  (0.019275968428179257, 'Population_NHW'),
#  (0.01901563279384528, 'Percent_Vaccinated'),
#  (0.018820837299045115, 'Household_Income_Hispanic'),
#  (0.018459952424390143, 'Food_Environment_Index'),
#  (0.018320181844456676, 'Mental_Health_Provider_Rate'),
#  (0.018261744853027027, 'Dentist_Rate'),
#  (0.01788302587664717, 'Primary_Care_Physicians_Rate'),
#  (0.017654787230311338, 'Percent_Uninsured'),
#  (0.017314540550034892, 'Percent_Single_Parent_Households'),
#  (0.01718930251849401, 'Percent_Homeowners'),
#  (0.016936754089239607, 'Percent_Adults_with_Diabetes'),
#  (0.016755799092010533, 'Percent_Long_Commute'),
#  (0.016745804724410045, 'High_School_Graduation_Rate'),
#  (0.016618239223819147, 'Percent_Severe_Housing_Problems'),
#  (0.014888624850340445, 'Household_Income_Black'),
#  (0.014346908341586091, 'Percent_Limited_Access_to_Healthy_Foods'),
#  (0.011926044928052366, 'Household_Income_Asian'),
#  (0.011153113150189247, 'Household_Income_AIAN'),
#  (0.004473165305655044, 'Percent_Children_in_Poverty'),
#  (0.0037440856544847965, 'Percent_Severe_Housing_Cost_Burden'),
#  (0.0026932420776531857, 'Presence_of_Water_Violation'),
#  (0.0006746198350135414, 'Teen_Birth_Rate')]
